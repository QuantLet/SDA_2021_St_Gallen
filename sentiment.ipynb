# %%
import pandas as pd
import numpy as np
import re
from pandas.core.frame import DataFrame
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
#create a csv reader
reader = pd.read_csv("Bitcoin_tweets_2.csv",chunksize=100,low_memory=False)
#create a dataframe and check the function of chunksize later
chunk1_data = pd.concat(reader, ignore_index=True)

# %%
print(chunk1_data.shape)
chunk1_data
# Out:
# (1945310, 13)
#                                         user_name    user_location  \
# 0                                   DeSota Wilson      Atlanta, GA
# 1                                        CryptoND              NaN
# 2                                       Tdlmatias  London, England
# 3                            Crypto is the future              NaN
# 4        Alex Kirchmaier 🇦🇹🇸🇪 #FactsSuperspreader           Europa
# ...                                           ...              ...
# 1945305                                       Ali              NaN
# 1945306                                 hossin kh              NaN
# 1945307                              TRENDsMarket              NaN
# 1945308                                       Ali              NaN
# 1945309                                       Ali              NaN
#
#                                           user_description  \
# 0        Biz Consultant, real estate, fintech, startups...
# 1        😎 BITCOINLIVE is a Dutch platform aimed at inf...
# 2        IM Academy : The best #forex, #SelfEducation, ...
# 3        I will post a lot of buying signals for BTC tr...
# 4        Co-founder @RENJERJerky | Forbes 30Under30 | I...
# ...                                                    ...
# 1945305  @TsukiverseToken will be releasing game on And...
# 1945306                                                NaN
# 1945307  Information and Comments Found Here Are Not In...
# 1945308  @TsukiverseToken will be releasing game on And...
# 1945309  @TsukiverseToken will be releasing game on And...
#
#                 user_created  user_followers user_friends user_favourites  \
# 0        2009-04-26 20:05:09          8534.0         7605            4838
# 1        2019-10-17 20:12:10          6769.0         1532           25483
# 2        2014-11-10 10:50:37           128.0          332             924
# 3        2019-09-28 16:48:12           625.0          129              14
# 4        2016-02-03 13:15:55          1249.0         1472           10482
# ...                      ...             ...          ...             ...
# 1945305  2021-04-15 17:25:34            12.0           51            1227
# 1945306  2018-11-08 22:59:01             5.0           15             655
# 1945307  2021-08-18 23:10:11            64.0            0               0
# 1945308  2021-04-15 17:25:34            12.0           51            1227
# 1945309  2021-04-15 17:25:34            12.0           51            1227
#
#         user_verified                 date  \
# 0               False  2021-02-10 23:59:04
# 1               False  2021-02-10 23:58:48
# 2               False  2021-02-10 23:54:48
# 3               False  2021-02-10 23:54:33
# 4               False  2021-02-10 23:54:06
# ...               ...                  ...
# 1945305         False  2021-11-25 19:12:31
# 1945306         False  2021-11-25 19:12:28
# 1945307         False  2021-11-25 19:12:27
# 1945308         False  2021-11-25 19:12:24
# 1945309         False  2021-11-25 19:12:18
#
#                                                       text  \
# 0        Blue Ridge Bank shares halted by NYSE after #b...
# 1        😎 Today, that's this #Thursday, we will do a "...
# 2        Guys evening, I have read this article about B...
# 3        $BTC A big chance in a billion! Price: \487264...
# 4        This network is secured by 9 508 nodes as of t...
# ...                                                    ...
# 1945305  @Tsuga007 @AltCryptoGems Something Big is on t...
# 1945306  @Tsuga007 @AltCryptoGems Something Big is on t...
# 1945307  MATIC__   CRYPTO    PRİCE WİLL RİSE_|__   #USD...
# 1945308  @Tsuga007 @AltCryptoGems Something Big is on t...
# 1945309  @Tsuga007 @AltCryptoGems Something Big is on t...
#
#                                                   hashtags  \
# 0                                              ['bitcoin']
# 1                ['Thursday', 'Btc', 'wallet', 'security']
# 2                                                      NaN
# 3                       ['Bitcoin', 'FX', 'BTC', 'crypto']
# 4                                                  ['BTC']
# ...                                                    ...
# 1945305  ['Tsuga', 'PlaytoEarn', 'game', '𝙏𝙎𝙐𝙂𝘼', 'BNB'...
# 1945306  ['Tsuga', 'PlaytoEarn', 'game', '𝙏𝙎𝙐𝙂𝘼', 'BNB'...
# 1945307  ['USDEGP', 'CNHTRY', 'USDHUF', 'GBPCHF', 'SAR'...
# 1945308  ['Tsuga', 'PlaytoEarn', 'game', '𝙏𝙎𝙐𝙂𝘼', 'BNB'...
# 1945309  ['Tsuga', 'PlaytoEarn', 'game', '𝙏𝙎𝙐𝙂𝘼', 'BNB'...
#
#                       source is_retweet
# 0            Twitter Web App      False
# 1        Twitter for Android      False
# 2            Twitter Web App      False
# 3                    dlvr.it      False
# 4            Twitter Web App      False
# ...                      ...        ...
# 1945305  Twitter for Android      False
# 1945306      Twitter Web App      False
# 1945307      Twitter Web App      False
# 1945308  Twitter for Android      False
# 1945309  Twitter for Android      False
#
# [1945310 rows x 13 columns]

# %%
#chunksize not working
#clean the dataframe, drop the row where the "text" column is NaN
df=chunk1_data.dropna(subset=['text']).reset_index(drop=True)
print(df.shape)
df.tail(20)
# Out:
# (1944261, 13)
#                                                  user_name  \
# 1944241                                               reza
# 1944242                                          topstonks
# 1944243                                          Sobremesa
# 1944244                                       Crypto Vegan
# 1944245                                             slomax
# 1944246                                       Crypto Vegan
# 1944247                                          Tech_Team
# 1944248                                          hossin kh
# 1944249                                          Degendona
# 1944250                                               LMSC
# 1944251  Official Influencer | tranche : french for $SLICE
# 1944252                         be my friend, let me learn
# 1944253                                         alamin1997
# 1944254                                          Degendona
# 1944255                                       Crypto Vegan
# 1944256                                                Ali
# 1944257                                          hossin kh
# 1944258                                       TRENDsMarket
# 1944259                                                Ali
# 1944260                                                Ali
#
#                     user_location  \
# 1944241                       NaN
# 1944242                       NaN
# 1944243                       NaN
# 1944244                       NaN
# 1944245                    slough
# 1944246                       NaN
# 1944247                    Canada
# 1944248                       NaN
# 1944249                       NaN
# 1944250                       NaN
# 1944251  Somewhere Printing Money
# 1944252                       NaN
# 1944253                       NaN
# 1944254                       NaN
# 1944255                       NaN
# 1944256                       NaN
# 1944257                       NaN
# 1944258                       NaN
# 1944259                       NaN
# 1944260                       NaN
#
#                                           user_description  \
# 1944241                                         i love you
# 1944242  Wanna know where #stonks are in the hype cycle...
# 1944243                                          Sobremesa
# 1944244  @AURofficial_\nhttps://t.co/kLwbQPX7s0\nLifeti...
# 1944245                          crypto fanatic love $koda
# 1944246  @AURofficial_\nhttps://t.co/kLwbQPX7s0\nLifeti...
# 1944247  Software teams with highly talented members/#C...
# 1944248                                                NaN
# 1944249                                                NaN
# 1944250  Innovation that will turbo charge World's econ...
# 1944251              | Bounty Hunter \n| Crypto Influencer
# 1944252  music and cinema criticist/love specialist/rom...
# 1944253                                       Crypto Lover
# 1944254                                                NaN
# 1944255  @AURofficial_\nhttps://t.co/kLwbQPX7s0\nLifeti...
# 1944256  @TsukiverseToken will be releasing game on And...
# 1944257                                                NaN
# 1944258  Information and Comments Found Here Are Not In...
# 1944259  @TsukiverseToken will be releasing game on And...
# 1944260  @TsukiverseToken will be releasing game on And...
#
#                 user_created  user_followers user_friends user_favourites  \
# 1944241  2020-09-25 10:46:30            37.0        169.0          2219.0
# 1944242  2020-01-08 17:10:46          2965.0       1184.0           149.0
# 1944243  2021-06-01 19:45:39            14.0         51.0            15.0
# 1944244  2012-11-04 16:24:02           178.0       1104.0         12923.0
# 1944245  2011-09-24 17:33:43          3158.0        230.0           679.0
# 1944246  2012-11-04 16:24:02           178.0       1104.0         12923.0
['Tsuga', 'PlaytoEarn', 'game', '𝙏𝙎𝙐𝙂𝘼', 'BNB'...
# 1944249  ['BTC', 'BSC', 'Gem', 'x1000', 'Samura', 'Samu...
# 1944250  ['MANA', 'Mars', 'Moon', 'Decentraland', 'btc'...
# 1944251  ['Bit', 'Store', 'Giveaway', 'BTC', 'Crypto', ...
# 1944252                                            ['btc']
# 1944253  ['GoldSea', 'NFTs', 'BSC', 'art', 'gaming', 'C...
# 1944254  ['BTC', 'BSC', 'Gem', 'x1000', 'Samura', 'Samu...
# 1944255  ['Aurum', 'socialmedia', 'BlackFriday', 'Disco...
# 1944256  ['Tsuga', 'PlaytoEarn', 'game', '𝙏𝙎𝙐𝙂𝘼', 'BNB'...
# 1944257  ['Tsuga', 'PlaytoEarn', 'game', '𝙏𝙎𝙐𝙂𝘼', 'BNB'...
# 1944258  ['USDEGP', 'CNHTRY', 'USDHUF', 'GBPCHF', 'SAR'...
# 1944259  ['Tsuga', 'PlaytoEarn', 'game', '𝙏𝙎𝙐𝙂𝘼', 'BNB'...
# 1944260  ['Tsuga', 'PlaytoEarn', 'game', '𝙏𝙎𝙐𝙂𝘼', 'BNB'...
#
#                       source is_retweet
# 1944241  Twitter for Android      False
# 1944242                  NaN        NaN
# 1944243      Twitter Web App      False
# 1944244      Twitter Web App      False
# 1944245   Twitter for iPhone      False
# 1944246      Twitter Web App      False
# 1944247  Twitter for Android      False
# 1944248      Twitter Web App      False
# 1944249      Twitter Web App      False
# 1944250  Twitter for Android      False
# 1944251      Twitter Web App      False
# 1944252      Twitter Web App      False
# 1944253      Twitter Web App      False
# 1944254      Twitter Web App      False
# 1944255      Twitter Web App      False
# 1944256  Twitter for Android      False
# 1944257      Twitter Web App      False
# 1944258      Twitter Web App      False
# 1944259  Twitter for Android      False
# 1944260  Twitter for Android      False

# %%
#We discovered tweet in row no.1489542 is from CryptoBot, try to drop all the tweets that are from crytobot 
df["source"]= df["source"].apply(str)
df["source"]= df["source"].str.lower()
df_cleaned = df[~df["source"].str.contains("bot")]
print(df_cleaned.shape)
df_cleaned.tail(20)
# Out:
# (1863152, 13)
#                                                  user_name  \
# 1944241                                               reza
# 1944242                                          topstonks
# 1944243                                          Sobremesa
# 1944244                                       Crypto Vegan
# 1944245                                             slomax
# 1944246                                       Crypto Vegan
# 1944247                                          Tech_Team
# 1944248                                          hossin kh
# 1944249                                          Degendona
# 1944250                                               LMSC
# 1944251  Official Influencer | tranche : french for $SLICE
# 1944252                         be my friend, let me learn
# 1944253                                         alamin1997
# 1944254                                          Degendona
# 1944255                                       Crypto Vegan
# 1944256                                                Ali
# 1944257                                          hossin kh
# 1944258                                       TRENDsMarket
# 1944259                                                Ali
# 1944260                                                Ali
#
#                     user_location  \
# 1944241                       NaN
# 1944242                       NaN
# 1944243                       NaN
# 1944244                       NaN
# 1944245                    slough
# 1944246                       NaN
# 1944247                    Canada
# 1944248                       NaN
# 1944249                       NaN
# 1944250                       NaN
# 1944251  Somewhere Printing Money
# 1944252                       NaN
# 1944253                       NaN
# 1944254                       NaN
# 1944255                       NaN
# 1944256                       NaN
# 1944257                       NaN
# 1944258                       NaN
# 1944259                       NaN
# 1944260                       NaN
#
#                                           user_description  \
# 1944241                                         i love you
# 1944242  Wanna know where #stonks are in the hype cycle...
# 1944243                                          Sobremesa
# 1944244  @AURofficial_\nhttps://t.co/kLwbQPX7s0\nLifeti...
# 1944245                          crypto fanatic love $koda
# 1944246  @AURofficial_\nhttps://t.co/kLwbQPX7s0\nLifeti...
# 1944247  Software teams with highly talented members/#C...
# 1944248                                                NaN
# 1944249                                                NaN
# 1944250  Innovation that will turbo charge World's econ...
@Tsuga007 @AltCryptoGems Something Big is on t...
# 1944249  @AntoAttorre @Samuratoken\n GEM FOR 2021\n\n70...
# 1944250  @Investments_CEO #MANA to #Mars via #Moon🛸🛸\n#...
# 1944251  #Bit.Store #Store #Giveaway #BTC #Crypto #Soci...
# 1944252       thx for playing #btc https://t.co/hKUhQ2S4JN
# 1944253  @GoldSeaNFT I really believe that this project...
# 1944254  @peterhuntcrypto @Samuratoken\n GEM FOR 2021\n...
# 1944255  @OpeoluwaFalodun @cryptojm99 @AURofficial_ The...
# 1944256  @Tsuga007 @AltCryptoGems Something Big is on t...
# 1944257  @Tsuga007 @AltCryptoGems Something Big is on t...
# 1944258  MATIC__   CRYPTO    PRİCE WİLL RİSE_|__   #USD...
# 1944259  @Tsuga007 @AltCryptoGems Something Big is on t...
# 1944260  @Tsuga007 @AltCryptoGems Something Big is on t...
#
#                                                   hashtags  \
# 1944241  ['Tsuga', 'PlaytoEarn', 'game', '𝙏𝙎𝙐𝙂𝘼', 'BNB'...
# 1944242                                                NaN
# 1944243  ['NFT', 'nfts', 'NFTGiveaway', 'nftcollector',...
# 1944244  ['Aurum', 'socialmedia', 'BlackFriday', 'Disco...
# 1944245  ['cryptocurrency', 'BNB', 'CoinMarketCap', 'bt...
# 1944246  ['Aurum', 'socialmedia', 'BlackFriday', 'Disco...
# 1944247                                            ['btc']
# 1944248  ['Tsuga', 'PlaytoEarn', 'game', '𝙏𝙎𝙐𝙂𝘼', 'BNB'...
# 1944249  ['BTC', 'BSC', 'Gem', 'x1000', 'Samura', 'Samu...
# 1944250  ['MANA', 'Mars', 'Moon', 'Decentraland', 'btc'...
# 1944251  ['Bit', 'Store', 'Giveaway', 'BTC', 'Crypto', ...
# 1944252                                            ['btc']
# 1944253  ['GoldSea', 'NFTs', 'BSC', 'art', 'gaming', 'C...
# 1944254  ['BTC', 'BSC', 'Gem', 'x1000', 'Samura', 'Samu...
# 1944255  ['Aurum', 'socialmedia', 'BlackFriday', 'Disco...
# 1944256  ['Tsuga', 'PlaytoEarn', 'game', '𝙏𝙎𝙐𝙂𝘼', 'BNB'...
# 1944257  ['Tsuga', 'PlaytoEarn', 'game', '𝙏𝙎𝙐𝙂𝘼', 'BNB'...
# 1944258  ['USDEGP', 'CNHTRY', 'USDHUF', 'GBPCHF', 'SAR'...
# 1944259  ['Tsuga', 'PlaytoEarn', 'game', '𝙏𝙎𝙐𝙂𝘼', 'BNB'...
# 1944260  ['Tsuga', 'PlaytoEarn', 'game', '𝙏𝙎𝙐𝙂𝘼', 'BNB'...
#
#                       source is_retweet
# 1944241  twitter for android      False
# 1944242                  nan        NaN
# 1944243      twitter web app      False
# 1944244      twitter web app      False
# 1944245   twitter for iphone      False
# 1944246      twitter web app      False
# 1944247  twitter for android      False
# 1944248      twitter web app      False
# 1944249      twitter web app      False
# 1944250  twitter for android      False
# 1944251      twitter web app      False
# 1944252      twitter web app      False
# 1944253      twitter web app      False
# 1944254      twitter web app      False
# 1944255      twitter web app      False
# 1944256  twitter for android      False
# 1944257      twitter web app      False
# 1944258      twitter web app      False
# 1944259  twitter for android      False
# 1944260  twitter for android      False

# %%
#drop columns=['user_name', 'user_created','user_verified','hashtags','source',is_retweet'] 
btc=df_cleaned.loc[:,["date","text","user_location","user_description","user_followers","user_friends"]]
btc
# Out:
#                         date  \
# 0        2021-02-10 23:59:04
# 1        2021-02-10 23:58:48
# 2        2021-02-10 23:54:48
# 3        2021-02-10 23:54:33
# 4        2021-02-10 23:54:06
# ...                      ...
# 1944256  2021-11-25 19:12:31
# 1944257  2021-11-25 19:12:28
# 1944258  2021-11-25 19:12:27
# 1944259  2021-11-25 19:12:24
# 1944260  2021-11-25 19:12:18
#
#                                                       text    user_location  \
# 0        Blue Ridge Bank shares halted by NYSE after #b...      Atlanta, GA
# 1        😎 Today, that's this #Thursday, we will do a "...              NaN
# 2        Guys evening, I have read this article about B...  London, England
# 3        $BTC A big chance in a billion! Price: \487264...              NaN
# 4        This network is secured by 9 508 nodes as of t...           Europa
# ...                                                    ...              ...
# 1944256  @Tsuga007 @AltCryptoGems Something Big is on t...              NaN
# 1944257  @Tsuga007 @AltCryptoGems Something Big is on t...              NaN
# 1944258  MATIC__   CRYPTO    PRİCE WİLL RİSE_|__   #USD...              NaN
# 1944259  @Tsuga007 @AltCryptoGems Something Big is on t...              NaN
# 1944260  @Tsuga007 @AltCryptoGems Something Big is on t...              NaN
#
#                                           user_description  user_followers  \
# 0        Biz Consultant, real estate, fintech, startups...          8534.0
# 1        😎 BITCOINLIVE is a Dutch platform aimed at inf...          6769.0
# 2        IM Academy : The best #forex, #SelfEducation, ...           128.0
# 3        I will post a lot of buying signals for BTC tr...           625.0
# 4        Co-founder @RENJERJerky | Forbes 30Under30 | I...          1249.0
# ...                                                    ...             ...
# 1944256  @TsukiverseToken will be releasing game on And...            12.0
# 1944257                                                NaN             5.0
# 1944258  Information and Comments Found Here Are Not In...            64.0
# 1944259  @TsukiverseToken will be releasing game on And...            12.0
# 1944260  @TsukiverseToken will be releasing game on And...            12.0
#
#         user_friends
# 0               7605
# 1               1532
# 2                332
# 3                129
# 4               1472
# ...              ...
# 1944256           51
# 1944257           15
# 1944258            0
# 1944259           51
# 1944260           51
#
# [1863152 rows x 6 columns]

# %%
btc[(btc['date'] > '2021-05-01') & (btc['date'] < '2021-05-06')]
# Out:
# Empty DataFrame
# Columns: [date, text, user_location, user_description, user_followers, user_friends]
# Index: []

# %%
btc["text"] = btc["text"].apply(str)
tweets = btc["text"].tolist()
tweets[0:11]
# Out:
# ['Blue Ridge Bank shares halted by NYSE after #bitcoin ATM announcement https://t.co/xaaZmaJKiV @MyBlueRidgeBank… https://t.co/sgBxMkP1SI',
#  '😎 Today, that\'s this #Thursday, we will do a "🎬 Take 2" with our friend @LeoWandersleb, #Btc #wallet #security expe… https://t.co/go6aDgRml5',
#  'Guys evening, I have read this article about BTC and would like to share with you all - https://t.co/QxCZgmuy3B… https://t.co/o6wn7ppkVY',
#  '$BTC A big chance in a billion! Price: \\4872644.0 (2021/02/11 08:51) #Bitcoin #FX #BTC #crypto',
#  'This network is secured by 9 508 nodes as of today. Soon, the biggest bears will recognise: #BTC in too big to fail… https://t.co/1XovDA8rKw',
#  '💹 Trade #Crypto on #Binance \n\n📌 Enjoy #Cashback 10% of the Trading fee\n📌 Sign up link 👉 https://t.co/T4WttWeohc… https://t.co/Fc7dG5oI8W',
#  '🔄 Prices update in $EUR (1 hour):\n\n$BTC   - 37082.1 €  (-0.51 %)\n$ETH   - 1441.59 €  (+0.21 %)\n$XRP   - 0.42 €    (… https://t.co/y3wlhAv2SX',
#  '#BTC #Bitcoin #Ethereum #ETH #Crypto #cryptotrading \n\n$RSR I know i told you guys the target was $0.060, i know we… https://t.co/bvEtSnhs67',
#  '.@Tesla’s #bitcoin investment is revolutionary for #crypto but other firms may not do the same just yet - @JPMorgan… https://t.co/WyKWfh0ELw',
#  'Annnd #btc #Bitcoin is headed even higher now... https://t.co/EHAduI087d',
#  '🔄 Prices update in $USDT (1 hour):\n\n$BTC - 44853.08 $     (-0.48 %)\n$ETH - 1740.0 $       (-0.02 %)\n$XRP - 0.5 $… https://t.co/v5oGvW7kLm']

# %%
def processTweet(tweet): #start process_tweet
    # process the tweets
    #Convert to lower case
    tweet = tweet.lower()
    #Convert www.* or https?://* to URL
    tweet = re.sub('((www\.[^\s]+)|(https?://[^\s]+))','URL',tweet)
    #Convert @username to AT_USER
    tweet = re.sub('@[^\s]+','AT_USER',tweet)
    #Remove additional white spaces
    tweet = re.sub('[\s]+', ' ', tweet)
    #Replace #word with word
    tweet = re.sub(r'#([^\s]+)', r'\1', tweet)#trim
    tweet = tweet.strip('\'"')
    return tweet
#end
tweets_cleaned = []
#Read the tweets one by one and process it
for i in range (0,len(tweets)):
    processedTweet = processTweet(tweets[i])
    tweets_cleaned.append(processedTweet)
print(len(tweets_cleaned))
tweets_cleaned[0:11]
# Out:
# 1863152
# ['blue ridge bank shares halted by nyse after bitcoin atm announcement URL AT_USER URL',
#  '😎 today, that\'s this thursday, we will do a "🎬 take 2" with our friend AT_USER btc wallet security expe… URL',
#  'guys evening, i have read this article about btc and would like to share with you all - URL URL',
#  '$btc a big chance in a billion! price: \\4872644.0 (2021/02/11 08:51) bitcoin fx btc crypto',
#  'this network is secured by 9 508 nodes as of today. soon, the biggest bears will recognise: btc in too big to fail… URL',
#  '💹 trade crypto on binance 📌 enjoy cashback 10% of the trading fee 📌 sign up link 👉 URL URL',
#  '🔄 prices update in $eur (1 hour): $btc - 37082.1 € (-0.51 %) $eth - 1441.59 € (+0.21 %) $xrp - 0.42 € (… URL',
#  'btc bitcoin ethereum eth crypto cryptotrading $rsr i know i told you guys the target was $0.060, i know we… URL',
#  '.AT_USER bitcoin investment is revolutionary for crypto but other firms may not do the same just yet - AT_USER URL',
#  'annnd btc bitcoin is headed even higher now... URL',
#  '🔄 prices update in $usdt (1 hour): $btc - 44853.08 $ (-0.48 %) $eth - 1740.0 $ (-0.02 %) $xrp - 0.5 $… URL']

# %%
vader = SentimentIntensityAnalyzer()
def getCoumpoundScore(Tweets):
    score = vader.polarity_scores(Tweets)['compound']
    return score
scores = []
#Read the tweets one by one and get the sentiment score
for i in range (0,len(tweets_cleaned)):
    tweets_score = getCoumpoundScore(tweets_cleaned[i])
    scores.append(tweets_score)   
#store the tweet with polarity score in a dictionary
df = {"tweets": tweets_cleaned, "score" : scores}
data = DataFrame(df)#transfer into a dataframe
print(data.shape)
data.head(11)
# Out:
# (1863152, 2)
#                                                tweets   score
# 0   blue ridge bank shares halted by nyse after bi...  0.2960
# 1   😎 today, that's this thursday, we will do a "🎬...  0.8225
# 2   guys evening, i have read this article about b...  0.5719
# 3   $btc a big chance in a billion! price: \487264...  0.3164
# 4   this network is secured by 9 508 nodes as of t...  0.4019
# 5   💹 trade crypto on binance 📌 enjoy cashback 10%...  0.4939
# 6   🔄 prices update in $eur (1 hour): $btc - 37082... -0.2023
# 7   btc bitcoin ethereum eth crypto cryptotrading ...  0.0000
# 8   .AT_USER bitcoin investment is revolutionary f...  0.0000
# 9   annnd btc bitcoin is headed even higher now......  0.0000
# 10  🔄 prices update in $usdt (1 hour): $btc - 4485... -0.2023

# %%
merged_data = pd.concat([btc, data], axis=1).reset_index(drop=True)
merged_data = merged_data.drop('text', axis=1)
print(merged_data.shape)
merged_data.head(10)
# Out:
# (1941546, 7)
#                   date    user_location  \
# 0  2021-02-10 23:59:04      Atlanta, GA
# 1  2021-02-10 23:58:48              NaN
# 2  2021-02-10 23:54:48  London, England
# 3  2021-02-10 23:54:33              NaN
# 4  2021-02-10 23:54:06           Europa
# 5  2021-02-10 23:53:30    Bkk, Thailand
# 6                  NaN              NaN
# 7  2021-02-10 23:52:42              NaN
# 8  2021-02-10 23:52:25              NaN
# 9  2021-02-10 23:52:08      Atlanta, GA
#
#                                     user_description  user_followers  \
# 0  Biz Consultant, real estate, fintech, startups...          8534.0
# 1  😎 BITCOINLIVE is a Dutch platform aimed at inf...          6769.0
# 2  IM Academy : The best #forex, #SelfEducation, ...           128.0
# 3  I will post a lot of buying signals for BTC tr...           625.0
# 4  Co-founder @RENJERJerky | Forbes 30Under30 | I...          1249.0
# 5  I'm a cat slave 🐱 Interested in Blockchain · T...           742.0
# 6                                                NaN             NaN
# 7  Stay updated on the main cryptocurrencies of t...          4052.0
# 8  Technical Analyst | Trader\n\nNo certainty, on...           104.0
# 9  Biz Consultant, real estate, fintech, startups...          8534.0
#
#   user_friends                                             tweets   score
# 0         7605  blue ridge bank shares halted by nyse after bi...  0.2960
# 1         1532  😎 today, that's this thursday, we will do a "🎬...  0.8225
# 2          332  guys evening, i have read this article about b...  0.5719
# 3          129  $btc a big chance in a billion! price: \487264...  0.3164
# 4         1472  this network is secured by 9 508 nodes as of t...  0.4019
# 5          716  💹 trade crypto on binance 📌 enjoy cashback 10%...  0.4939
# 6          NaN  🔄 prices update in $eur (1 hour): $btc - 37082... -0.2023
# 7            1  btc bitcoin ethereum eth crypto cryptotrading ...  0.0000
# 8           41  .AT_USER bitcoin investment is revolutionary f...  0.0000
# 9         7605  annnd btc bitcoin is headed even higher now......  0.0000

# %%
#transfer date's string type into date time in order to do time dynamic analysis
#Error message:'Unknown string format:', "['ETH', 'BTC', 'Bitcoin']", also NaN is contained in date
#So clean the date column
da = merged_data.dropna(subset=['date']).reset_index(drop=True)
da = da[~da["date"].str.contains("ETH" or "BTC" or "Bitcoin")] #only two are detected and erased
print(da.shape)
# Out:
# (1863150, 7)

# %%
da['date'] = pd.to_datetime(da['date'], format='%Y-%m-%d %H:%M:%S', errors='coerce')
print(type(da['date'][1]))
#delete value as "NaT" in date
da = da.dropna(subset=['date']).reset_index(drop=True)
print(da.shape)
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# (1863137, 7)

# %%
da = da.sort_values(by="date")
da.head(10)
# Out:
#                      date                  user_location  \
# 20792 2021-02-05 10:52:04     Frankfurt am Main, Germany
# 20793 2021-02-05 10:52:04     Frankfurt am Main, Germany
# 20791 2021-02-05 10:52:06     Frankfurt am Main, Germany
# 20790 2021-02-05 10:52:07     Frankfurt am Main, Germany
# 20789 2021-02-05 10:52:26       Edam-Volendam, Nederland
# 20788 2021-02-05 10:53:49                            NaN
# 20787 2021-02-05 10:54:52                Los Angeles, CA
# 20786 2021-02-05 10:57:05  Dubai - United Arab Emirates
# 20785 2021-02-05 10:58:03                      Australia
# 20784 2021-02-05 10:58:36                         Jungle
#
# 5          388  klv just broke out of a bullflag. here is an i... -0.5267
# 6           52  AT_USER right here w/ AT_USER URL referral cod...  0.0000
# 7          288       AT_USER keep goin and have luck! btc bitcoin  0.5093
# 8         1085  AT_USER AT_USER right here w/ AT_USER URL refe...  0.0000
# 9            0  btc ethereum bitcoin eth binance cyrpto reef d...  0.0000

# %%
da.to_csv('btc_score_v1.csv',index=False)

# %%
d_raw = da.loc[:,["date","score"]]
d_hourly=d_raw.groupby(pd.Grouper(key='date',freq='H')).agg([np.mean, np.std, np.var])
d_hourly
# Out:
#                         score
#                          mean       std       var
# date
# 2021-02-05 10:00:00  0.091227  0.317950  0.101092
# 2021-02-05 11:00:00  0.167448  0.368591  0.135859
# 2021-02-05 12:00:00  0.157152  0.374703  0.140403
# 2021-02-05 13:00:00  0.177828  0.386389  0.149296
# 2021-02-05 14:00:00  0.133480  0.395140  0.156135
# ...                       ...       ...       ...
# 2021-11-26 19:00:00  0.252113  0.425334  0.180909
# 2021-11-26 20:00:00  0.218467  0.470058  0.220955
# 2021-11-26 21:00:00  0.229934  0.450842  0.203258
# 2021-11-26 22:00:00  0.229789  0.421192  0.177402
# 2021-11-26 23:00:00  0.210741  0.498201  0.248204
#
# [7070 rows x 3 columns]

# %%
d_hourly.to_csv('btc_score_hourly_raw.csv',index=True)

# %%
d_daily = d_raw.groupby(pd.Grouper(key='date',freq='D')).agg([np.mean, np.std, np.var])
d_daily.head(20)
# Out:
#                score
#                 mean       std       var
# date
# 2021-02-05  0.151515  0.375420  0.140940
# 2021-02-06  0.148199  0.356104  0.126810
# 2021-02-07  0.145060  0.340988  0.116273
# 2021-02-08  0.166337  0.355058  0.126066
# 2021-02-09  0.155760  0.362583  0.131466
# 2021-02-10  0.181649  0.364100  0.132569
# 2021-02-11       NaN       NaN       NaN
# 2021-02-12       NaN       NaN       NaN
# 2021-02-13  0.147921  0.364068  0.132545
# 2021-02-14  0.247778  0.394838  0.155897
# 2021-02-15  0.365897  0.416667  0.173612
# 2021-02-16       NaN       NaN       NaN
# 2021-02-17       NaN       NaN       NaN
# 2021-02-18  0.148784  0.362651  0.131515
# 2021-02-19  0.153861  0.360949  0.130284
# 2021-02-20       NaN       NaN       NaN
# 2021-02-21       NaN       NaN       NaN
# 2021-02-22  0.132034  0.372294  0.138603
# 2021-02-23       NaN       NaN       NaN
# 2021-02-24       NaN       NaN       NaN

# %%
d_daily.to_csv('btc_score_daily_raw.csv',index=True)

# %%
# load data if necessary
import pandas as pd
d_daily = pd.read_csv('data/btc_score_daily_raw.csv')

# %%
len(d_daily)
d_daily.tail()
# Out:
#            date      mean       std       var
# 290  2021-11-22       NaN       NaN       NaN
# 291  2021-11-23       NaN       NaN       NaN
# 292  2021-11-24       NaN       NaN       NaN
# 293  2021-11-25       NaN       NaN       NaN
# 294  2021-11-26  0.231743  0.433646  0.188049

# %%
df1= d_daily.interpolate()

# %%
df1.head(10)
# Out:
#          date      mean       std       var
# 0  2021-02-05  0.151515  0.375420  0.140940
# 1  2021-02-06  0.148199  0.356104  0.126810
# 2  2021-02-07  0.145060  0.340988  0.116273
# 3  2021-02-08  0.166337  0.355058  0.126066
# 4  2021-02-09  0.155760  0.362583  0.131466
# 5  2021-02-10  0.181649  0.364100  0.132569
# 6  2021-02-11  0.170406  0.364089  0.132561
# 7  2021-02-12  0.159163  0.364079  0.132553
# 8  2021-02-13  0.147921  0.364068  0.132545
# 9  2021-02-14  0.247778  0.394838  0.155897

# %%
clean_df = d_daily.dropna()
#clean_df = clean_df.set_index("date")
clean_df
# Out:
#            date      mean       std       var
# 0    2021-02-05  0.151515  0.375420  0.140940
# 1    2021-02-06  0.148199  0.356104  0.126810
# 2    2021-02-07  0.145060  0.340988  0.116273
# 3    2021-02-08  0.166337  0.355058  0.126066
# 4    2021-02-09  0.155760  0.362583  0.131466
# ..          ...       ...       ...       ...
# 279  2021-11-11  0.233276  0.437520  0.191423
# 280  2021-11-12  0.257182  0.448688  0.201321
# 286  2021-11-18  0.329639  0.464094  0.215383
# 287  2021-11-19  0.284013  0.465912  0.217074
# 294  2021-11-26  0.231743  0.433646  0.188049
#
# [95 rows x 4 columns]

# %%
df1.iloc[:,1]
# Out:
# 0      0.151515
# 1      0.148199
# 2      0.145060
# 3      0.166337
# 4      0.155760
#          ...
# 290    0.261612
# 291    0.254145
# 292    0.246678
# 293    0.239210
# 294    0.231743
# Name: mean, Length: 295, dtype: float64

# %%
import matplotlib.pyplot as plt
ts = pd.Series(df1.iloc[:,1])

ts.plot();

# %%
import seaborn as sns

sns.set(font_scale=1, rc={'text.usetex': True})
sns.set_style("whitegrid")

from matplotlib import rcParams
rcParams.update({'figure.autolayout': True})
plt.rcParams['axes.titlesize'] = 20

# %%
plt.rcParams["figure.autolayout"] = True

ax = sns.lineplot(x="date", y="mean", data=df1)
# plt.xticks(rotation=15)
plt.title('Twitter sentiment')
ax.set(xlabel='Date', ylabel='Sentiment')
plt.savefig('images/sentiment_transparent.png', dpi=400, transparent=True)
plt.show()
plt.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-d9e9762516f3> in <module>
#       5 plt.title('Twitter sentiment')
#       6 ax.set(xlabel='Date', ylabel='Sentiment')
# ----> 7 plt.savefig('images/sentiment_transparent.png', dpi=400, transparent=True)
#       8 plt.show()
#       9 plt.close()
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     857 def savefig(*args, **kwargs):
#     858     fig = gcf()
# --> 859     res = fig.savefig(*args, **kwargs)
#     860     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     861     return res
#
# ~\anaconda3\lib\site-packages\matplotlib\figure.py in savefig(self, fname, transparent, **kwargs)
#    2309                 patch.set_edgecolor('none')
#    2310
# -> 2311         self.canvas.print_figure(fname, **kwargs)
#    2312
#    2313         if transparent:
#
# ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2208
#    2209             try:
# -> 2210                 result = print_method(
#    2211                     filename,
#    2212                     dpi=dpi,
#
# ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py in wrapper(*args, **kwargs)
#    1637             kwargs.pop(arg)
#    1638
# -> 1639         return func(*args, **kwargs)
#    1640
#    1641     return wrapper
#
# ~\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     507             *metadata*, including the default 'Software' key.
#     508         """
# --> 509         FigureCanvasAgg.draw(self)
#     510         mpl.image.imsave(
#     511             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#
# ~\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     405              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     406               else nullcontext()):
# --> 407             self.figure.draw(self.renderer)
#     408             # A GUI class may be need to update a window using this draw, so
#     409             # don't forget to call the superclass.
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~\anaconda3\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1861
#    1862             self.patch.draw(renderer)
# -> 1863             mimage._draw_list_compositing_images(
#    1864                 renderer, self, artists, self.suppressComposite)
#    1865
#
# ~\anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~\anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2745             renderer.stop_rasterizing()
#    2746
# -> 2747         mimage._draw_list_compositing_images(renderer, self, artists)
#    2748
#    2749         renderer.close_group('axes')
#
# ~\anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in draw(self, renderer, *args, **kwargs)
#    1167
#    1168         for tick in ticks_to_draw:
# -> 1169             tick.draw(renderer)
#    1170
#    1171         # scale up the axis label box to also find the neighbors, not
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in draw(self, renderer)
#     289         for artist in [self.gridline, self.tick1line, self.tick2line,
#     290                        self.label1, self.label2]:
# --> 291             artist.draw(renderer)
#     292         renderer.close_group(self.__name__)
#     293         self.stale = False
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~\anaconda3\lib\site-packages\matplotlib\text.py in draw(self, renderer)
#     721
#     722                 if textobj.get_usetex():
# --> 723                     textrenderer.draw_tex(gc, x, y, clean_line,
#     724                                           textobj._fontproperties, angle,
#     725                                           mtext=mtext)
#
# ~\anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in draw_tex(self, gc, x, y, s, prop, angle, ismath, mtext)
#     252         texmanager = self.get_texmanager()
#     253
# --> 254         Z = texmanager.get_grey(s, size, self.dpi)
#     255         Z = np.array(Z * 255.0, np.uint8)
#     256
#
# ~\anaconda3\lib\site-packages\matplotlib\texmanager.py in get_grey(self, tex, fontsize, dpi)
#     386         alpha = self.grey_arrayd.get(key)
#     387         if alpha is None:
# --> 388             pngfile = self.make_png(tex, fontsize, dpi)
#     389             rgba = mpl.image.imread(os.path.join(self.texcache, pngfile))
#     390             self.grey_arrayd[key] = alpha = rgba[:, :, -1]
#
# ~\anaconda3\lib\site-packages\matplotlib\texmanager.py in make_png(self, tex, fontsize, dpi)
#     374                     and mpl._get_executable_info("dvipng").version != "1.16"):
#     375                 cmd.insert(1, "--freetype0")
# --> 376             self._run_checked_subprocess(cmd, tex)
#     377         return pngfile
#     378
#
# ~\anaconda3\lib\site-packages\matplotlib\texmanager.py in _run_checked_subprocess(self, command, tex)
#     273         _log.debug(cbook._pformat_subprocess(command))
#     274         try:
# --> 275             report = subprocess.check_output(command,
#     276                                              cwd=self.texcache,
#     277                                              stderr=subprocess.STDOUT)
#
# ~\anaconda3\lib\subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     409         kwargs['input'] = '' if kwargs.get('universal_newlines', False) else b''
#     410
# --> 411     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     412                **kwargs).stdout
#     413
#
# ~\anaconda3\lib\subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     489     with Popen(*popenargs, **kwargs) as process:
#     490         try:
# --> 491             stdout, stderr = process.communicate(input, timeout=timeout)
#     492         except TimeoutExpired as exc:
#     493             process.kill()
#
# ~\anaconda3\lib\subprocess.py in communicate(self, input, timeout)
#    1009                 self._stdin_write(input)
#    1010             elif self.stdout:
# -> 1011                 stdout = self.stdout.read()
#    1012                 self.stdout.close()
#    1013             elif self.stderr:
#
# KeyboardInterrupt:

# %%
fear = pd.read_csv("data/fear.alternative.me.csv")

# %%
fear.head()
# Out:
#          date  fng_value fng_classification
# 0  11-28-2021         27               Fear
# 1  11-27-2021         21       Extreme Fear
# 2  11-26-2021         47            Neutral
# 3  11-25-2021         32               Fear
# 4  11-24-2021         42               Fear

# %%
fear["date"] = pd.to_datetime(fear["date"])
fear = fear.set_index("date")
fear
# Out:
#             fng_value fng_classification
# date
# 2021-11-28         27               Fear
# 2021-11-27         21       Extreme Fear
# 2021-11-26         47            Neutral
# 2021-11-25         32               Fear
# 2021-11-24         42               Fear
# ...               ...                ...
# 2018-02-05         11       Extreme Fear
# 2018-02-04         24       Extreme Fear
# 2018-02-03         40               Fear
# 2018-02-02         15       Extreme Fear
# 2018-02-01         30               Fear
#
# [1394 rows x 2 columns]

# %%
fear.iloc[200:,0]
# Out:
# date
# 2021-05-12    68
# 2021-05-11    61
# 2021-05-10    72
# 2021-05-09    73
# 2021-05-08    67
#               ..
# 2018-02-05    11
# 2018-02-04    24
# 2018-02-03    40
# 2018-02-02    15
# 2018-02-01    30
# Name: fng_value, Length: 1194, dtype: int64

# %%
fear_ts = pd.Series(fear.iloc[:,0], index=pd.date_range("1/1/2021", "30/11/2021"))

fear_ts.plot();

# %%
ts.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-8a34b37f0ce9> in <module>
# ----> 1 ts.plot()
#
# NameError: name 'ts' is not defined
